# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("house-prices.csv")
df
# Out:
#      area      price
# 0    1567  177067.50
# 1    3345  511748.20
# 2    3722  404096.67
# 3    2783  357916.31
# 4    2949  362409.54
# ..    ...        ...
# 995  3442  434336.51
# 996  1530  211400.14
# 997  2102  172513.03
# 998  1551  200701.84
# 999  4244  456151.36
#
# [1000 rows x 2 columns]

# %%
print(df.columns)
# Out:
# Index(['area', 'price'], dtype='object')

# %%
df.columns = df.columns.str.strip()  # Remove any leading/trailing whitespace
df.columns = df.columns.str.lower()
plt.scatter(df['area'],df['price'])

# %%
plt.xlabel('area(squarefeet)')
plt.ylabel('price(Rs.)')
plt.scatter(df[['area']],df.price,color='black',marker='*')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[2100]])
# Out:
# E:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([263809.66007804])

# %%
reg.coef_
# Out:
# array([96.59803979])

# %%
reg.intercept_
# Out:
# 60953.776522719534

# %%
96.59803979*2600+60953.776522719534
# Out:
# 312108.67997671955

# %%
import pandas as pd 
d = pd.read_csv("area.csv")
d
# Out:
#    area
# 0  1000
# 1  2000
# 2  3000
# 3  4000
# 4  5000
# 5  6000
# 6  7000
# 7  8000
# 8  9000

# %%
d=pd.read_csv("area.csv")
d.head(5)
# Out:
#    area
# 0  1000
# 1  2000
# 2  3000
# 3  4000
# 4  5000

# %%
from sklearn import linear_model
df=pd.read_csv("house-prices.csv")
df
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
reg.predict(d)
# Out:
# array([157551.81631097, 254149.85609922, 350747.89588747, 447345.93567571,
#        543943.97546396, 640542.01525221, 737140.05504046, 833738.09482871,
#        930336.13461696])
